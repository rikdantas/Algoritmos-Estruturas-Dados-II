# %% [markdown]
# <a href="https://colab.research.google.com/github/rikdantas/Algoritmos-Estruturas-Dados-II/blob/main/U2T2/Requisito_02/source/U2T2_Requisito_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Requisito 02
# ### Aluno: Paulo Ricardo Dantas
# ### Matrícula: 20230000789
#
# ### Objetivo:
# **Fazer um gráfico de assortividade para cada rede escolhida**

# %%
# Importando bibliotecas

import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Baixando os datasets das 5 redes escolhidas
# !wget https://snap.stanford.edu/data/web-Google.txt.gz
# !wget https://snap.stanford.edu/data/wiki-Vote.txt.gz
# !wget https://snap.stanford.edu/data/email-Enron.txt.gz
# !wget https://snap.stanford.edu/data/web-Stanford.txt.gz
# !wget https://snap.stanford.edu/data/amazon0302.txt.gz

# %%
web_Google = nx.read_edgelist('web-Google.txt.gz', create_using=nx.DiGraph(), data=False)
wiki_Vote = nx.read_edgelist('wiki-Vote.txt.gz', create_using=nx.DiGraph(), data=False)
email_Enron = nx.read_edgelist('email-Enron.txt.gz', create_using=nx.Graph(), data=False)
web_Stanford = nx.read_edgelist('web-Stanford.txt.gz', create_using=nx.DiGraph(), data=False)
amazon0302 = nx.read_edgelist('amazon0302.txt.gz', create_using=nx.DiGraph(), data=False)

# %% [markdown]
# ### Criando gráfico para web_Google

# %%
# average degree of neighbors
degree, avg_neigh_degree = zip(*nx.average_degree_connectivity(web_Google).items())

# convert to list
degree = list(degree)
avg_neigh_degree = list(avg_neigh_degree)

plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(1,1,figsize=(12,8))

sns.regplot(x=degree,y=avg_neigh_degree,ax=ax)

ax.set_xlabel("Node Degree")
ax.set_ylabel("Average neigbhor degree")
ax.set_xlim(0,3000)

# adding a title
ax.set_title("Gráfico de assortatividade do web_Google")

plt.show()

# %% [markdown]
# ### Criando gráfico para wiki_Vote

# %%
# average degree of neighbors
degree, avg_neigh_degree = zip(*nx.average_degree_connectivity(wiki_Vote).items())

# convert to list
degree = list(degree)
avg_neigh_degree = list(avg_neigh_degree)

plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(1,1,figsize=(12,8))

sns.regplot(x=degree,y=avg_neigh_degree,ax=ax)

ax.set_xlabel("Node Degree")
ax.set_ylabel("Average neigbhor degree")
ax.set_xlim(0,600)

# adding a title
ax.set_title("Gráfico de assortatividade do wiki_Vote")

plt.show()

# %% [markdown]
# ### Criando gráfico para email_Enron

# %%
# average degree of neighbors
degree, avg_neigh_degree = zip(*nx.average_degree_connectivity(email_Enron).items())

# convert to list
degree = list(degree)
avg_neigh_degree = list(avg_neigh_degree)

plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(1,1,figsize=(12,8))

sns.regplot(x=degree,y=avg_neigh_degree,ax=ax)

ax.set_xlabel("Node Degree")
ax.set_ylabel("Average neigbhor degree")

# adding a title
ax.set_title("Gráfico de assortatividade do email_Enron")

plt.show()

# %% [markdown]
# ### Criando gráfico para web_Stanford

# %%
# average degree of neighbors
degree, avg_neigh_degree = zip(*nx.average_degree_connectivity(web_Stanford).items())

# convert to list
degree = list(degree)
avg_neigh_degree = list(avg_neigh_degree)

plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(1,1,figsize=(12,8))

sns.regplot(x=degree,y=avg_neigh_degree,ax=ax)

ax.set_xlabel("Node Degree")
ax.set_ylabel("Average neigbhor degree")

# adding a title
ax.set_title("Gráfico de assortatividade do web_Stanford")

plt.show()

# %% [markdown]
# ### Criando gráfico para amazon0302

# %%
# average degree of neighbors
degree, avg_neigh_degree = zip(*nx.average_degree_connectivity(amazon0302).items())

# convert to list
degree = list(degree)
avg_neigh_degree = list(avg_neigh_degree)

plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(1,1,figsize=(12,8))

sns.regplot(x=degree,y=avg_neigh_degree,ax=ax)

ax.set_xlabel("Node Degree")
ax.set_ylabel("Average neigbhor degree")
ax.set_xlim(0,300)

# adding a title
ax.set_title("Gráfico de assortatividade do amazon0302")

plt.show()
